# %%
import numpy as np
import matplotlib.pyplot as pl
import time
from joblib import Parallel, delayed

# %%
c = 3e8
G = 6.67e-11
pi = np.pi
const = 96/5*pi**(8/3)*(G/c**3)**(5/3)

# %%
def beta_step(beta, f0, f_max, phi_thresh):
    temp0 = beta**2*(5*phi_thresh)/(6*pi*f0)
    temp1 = (-5/8-3/8*(f0/f_max)**(8/3))/(f0/f_max)+1
    return -temp0/temp1

# %%
def steps_analytic(step, beta0, k):
    return 1/(-k*step+1/beta0)

# %%
f0 = 20
Mc = 1e-3* 2e30
f_max = 200
beta = const*f0**(8/3)*Mc**(5/3)
phi_thresh=pi/4
beta_max = const*f0**(8/3)*(1e-1*2e30)**(5/3)

# %%
beta_step(beta, f0, f_max, phi_thresh)/beta
# Out:
# 3.401490815956272e-11

# %%
k=-(5*phi_thresh)/(6*pi*f0)/((-5/8-3/8*(f0/f_max)**(8/3))/(f0/f_max)+1)
step_space = np.logspace(0, 12, 1000)
beta_arr = steps_analytic(step_space, beta, k)

# %%
pl.loglog(step_space, beta_arr)
pl.axhline(beta_max, c='r', ls='--')
pl.axvline(3e10, c='r', ls='--')

# %% [markdown]
# Specific arguments

# %%
f0 = 20
Mc = 1e-3 * 2e30
beta = const*f0**(8/3)*Mc**(5/3)
beta_max = const*200**(8/3)*(1e-1*2e30)**(5/3)

# %%
print(beta, beta_max)
# Out:
# 1.7169895555741805e-08 0.017169895555741808

# %%
steps=0
beta_arr=[]
while beta<beta_max:
    steps+=1000
    beta_arr.append(beta)
    beta += 1000*beta_step(beta, f0, f_max, phi_thresh)

# %%
pl.semilogy(steps, beta_arr)
print('%E' % steps)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_107049/1752615366.py in <module>
# ----> 1 pl.semilogy(steps, beta_arr)
#       2 print('%E' % steps)
#
# ~/anaconda3/envs/PBHs/lib/python3.7/site-packages/matplotlib/pyplot.py in semilogy(*args, **kwargs)
#    2823 @_copy_docstring_and_deprecators(Axes.semilogy)
#    2824 def semilogy(*args, **kwargs):
# -> 2825     return gca().semilogy(*args, **kwargs)
#    2826
#    2827
#
# ~/anaconda3/envs/PBHs/lib/python3.7/site-packages/matplotlib/axes/_axes.py in semilogy(self, *args, **kwargs)
#    1863         self.set_yscale('log', **d)
#    1864         return self.plot(
# -> 1865             *args, **{k: v for k, v in kwargs.items() if k not in d})
#    1866
#    1867     @_preprocess_data(replace_names=["x"], label_namer="x")
#
# ~/anaconda3/envs/PBHs/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633         for line in lines:
#    1634             self.add_line(line)
#
# ~/anaconda3/envs/PBHs/lib/python3.7/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     310                 this += args[0],
#     311                 args = args[1:]
# --> 312             yield from self._plot_args(this, kwargs)
#     313
#     314     def get_next_color(self):
#
# ~/anaconda3/envs/PBHs/lib/python3.7/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     496
#     497         if x.shape[0] != y.shape[0]:
# --> 498             raise ValueError(f"x and y must have same first dimension, but "
#     499                              f"have shapes {x.shape} and {y.shape}")
#     500         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (1,) and (29398859,)

# %% [markdown]
# ## With time grid

# %%
def t_max_calc(f0, beta, f_max):
    temp0 = 0.375/beta
    temp1 = 1-(f0/f_max)**(8/3)
    return temp0*temp1

# %%
f0 = 20
Mc = 1e-2 * 2e30
beta = const*f0**(8/3)*Mc**(5/3)
beta_max = const*200**(8/3)*(1e-1*2e30)**(5/3)

# %%
steps=0
beta_arr=[]
while beta<beta_max:
    beta_arr.append(beta)
    beta += 1000*beta_step(beta, f0, f_max, phi_thresh)
    steps += 1000*(1e7/t_max_calc(f0, beta, f_max))

# %%
print('%E' % steps)
# Out:
# 1.357095E+11
